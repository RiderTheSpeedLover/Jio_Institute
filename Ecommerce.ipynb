# %% [markdown]
# <a href="https://colab.research.google.com/github/RiderTheSpeedLover/Jio_Institute/blob/Ecommerce/Ecommerce.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load datasets
customers = pd.read_csv("customers.csv")
geolocation = pd.read_csv("geolocation.csv")
order_items = pd.read_csv("order_items.csv")
orders = pd.read_csv("orders (1).csv")
payments = pd.read_csv("payments.csv")
products = pd.read_csv("products.csv")
sellers = pd.read_csv("sellers.csv")

# Question 1: Total orders per product category (visualize)
order_items_products = order_items.merge(products, on="product_id")
categories_count = order_items_products["product category"].value_counts()
plt.figure(figsize=(12, 6))
categories_count.plot(kind='bar', color='skyblue')
plt.title("Total Orders per Product Category")
plt.xlabel("Product Category")
plt.ylabel("Total Orders")
plt.xticks(rotation=90)
plt.show()

# Question 2: Percentage of orders paid in installments (visualize)
installment_orders = payments[payments["payment_installments"] > 1]
installment_percentage = (len(installment_orders) / len(payments)) * 100
labels = ["One-time Payment", "Installments"]
sizes = [100 - installment_percentage, installment_percentage]
plt.figure(figsize=(6, 6))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', colors=['lightcoral', 'lightblue'])
plt.title("Percentage of Orders Paid in Installments")
plt.show()

# Question 3: Number of customers from each state (visualize)
customers_state_count = customers["customer_state"].value_counts()
plt.figure(figsize=(12, 6))
customers_state_count.plot(kind='bar', color='green')
plt.title("Number of Customers from Each State")
plt.xlabel("State")
plt.ylabel("Number of Customers")
plt.xticks(rotation=90)
plt.show()

# Question 4: Average number of products per order by customer city (visualize)
orders_customers = orders.merge(customers, on="customer_id")
orders_items_count = order_items.groupby("order_id")["order_item_id"].count().reset_index()
avg_products_city = orders_customers.merge(orders_items_count, on="order_id").groupby("customer_city")["order_item_id"].mean().sort_values(ascending=False)
plt.figure(figsize=(24, 6))
avg_products_city[:100].plot(kind='bar', color='orange')
plt.title("Average Number of Products per Order by City (Top 100)")
plt.xlabel("City")
plt.ylabel("Average Number of Products")
plt.xticks(rotation=90)
plt.show()

# Question 5: Relationship between product price and number of purchases
product_sales = order_items.groupby("product_id").agg({"order_id": "count", "price": "mean"}).reset_index()
sns.scatterplot(x=product_sales["price"], y=product_sales["order_id"], alpha=0.6)
plt.xlabel("Product Price")
plt.ylabel("Number of Times Purchased")
plt.title("Product Price vs. Number of Purchases")
plt.show()

# Question 6: Total revenue per seller and ranking
seller_revenue = order_items.groupby("seller_id")["price"].sum().reset_index().sort_values(by="price", ascending=False)
seller_revenue.columns = ["seller_id", "total_revenue"]
print(seller_revenue.head(10))  # Top 10 sellers by revenue

# Question 7: Moving average of order values per customer
# Merge datasets on order_id
merged_df = orders.merge(order_items, on="order_id")
# Calculate total order value per order
merged_df["order_value"] = merged_df["price"] + merged_df["freight_value"]
merged_df["order_purchase_timestamp"] = pd.to_datetime(merged_df["order_purchase_timestamp"])
merged_df = merged_df.sort_values(by=["customer_id", "order_purchase_timestamp"])
merged_df["moving_avg_order_value"] = merged_df.groupby("customer_id")["order_value"].transform(lambda x: x.rolling(window=3, min_periods=1).mean())
print(merged_df[["customer_id", "order_id", "order_purchase_timestamp", "order_value", "moving_avg_order_value"]].head(10))

output_path = "ecommerce_analysis.xlsx"
with pd.ExcelWriter(output_path) as writer:
    seller_revenue.to_excel(writer, sheet_name="Seller Revenue", index=False)
    merged_df.to_excel(writer, sheet_name="Moving Average Orders", index=False)

output_path

# Question 8: Customer retention rate
orders["order_purchase_timestamp"] = pd.to_datetime(orders["order_purchase_timestamp"])
first_order = orders.groupby("customer_id")["order_purchase_timestamp"].min().reset_index()
reorders = orders.merge(first_order, on="customer_id")
reorders = reorders[(reorders["order_purchase_timestamp_x"] > reorders["order_purchase_timestamp_y"]) & (reorders["order_purchase_timestamp_x"] <= reorders["order_purchase_timestamp_y"] + pd.DateOffset(months=6))]
retained_customers = reorders["customer_id"].nunique()
total_customers = first_order["customer_id"].nunique()
retention_rate = (retained_customers / total_customers) * 100
print(f"Retained Customers (reordered within 6 months): {retained_customers}")
print(f"Total Customers: {total_customers}")
print(f"Customer Retention Rate: {retention_rate:.2f}%")

# Question 9: Relationship between product weight, dimensions, and freight costs
# Merge order_items with products to get weight and dimensions
order_items_products = order_items.merge(products, on="product_id")

# Select relevant columns
order_items_products = order_items_products[["product_weight_g", "product_length_cm", "product_height_cm", "product_width_cm", "freight_value"]]

# Pairwise correlation heatmap (Shows correlation between weight, dimensions, and freight cost)
plt.figure(figsize=(8, 6))
sns.heatmap(order_items_products.corr(), annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Correlation Between Product Dimensions and Freight Cost")
plt.show()

# Scatterplots to visualize individual relationships
fig, axes = plt.subplots(2, 2, figsize=(12, 10))

sns.scatterplot(ax=axes[0, 0], x=order_items_products["product_weight_g"], y=order_items_products["freight_value"], alpha=0.5)
axes[0, 0].set_xlabel("Product Weight (g)")
axes[0, 0].set_ylabel("Freight Cost")
axes[0, 0].set_title("Product Weight vs Freight Cost")

sns.scatterplot(ax=axes[0, 1], x=order_items_products["product_length_cm"], y=order_items_products["freight_value"], alpha=0.5, color="orange")
axes[0, 1].set_xlabel("Product Length (cm)")
axes[0, 1].set_ylabel("Freight Cost")
axes[0, 1].set_title("Product Length vs Freight Cost")

sns.scatterplot(ax=axes[1, 0], x=order_items_products["product_height_cm"], y=order_items_products["freight_value"], alpha=0.5, color="green")
axes[1, 0].set_xlabel("Product Height (cm)")
axes[1, 0].set_ylabel("Freight Cost")
axes[1, 0].set_title("Product Height vs Freight Cost")

sns.scatterplot(ax=axes[1, 1], x=order_items_products["product_width_cm"], y=order_items_products["freight_value"], alpha=0.5, color="red")
axes[1, 1].set_xlabel("Product Width (cm)")
axes[1, 1].set_ylabel("Freight Cost")
axes[1, 1].set_title("Product Width vs Freight Cost")

plt.tight_layout()
plt.show()

# order_items_products = order_items.merge(products, on="product_id")
# sns.scatterplot(x=order_items_products["product_weight_g"], y=order_items_products["freight_value"], alpha=0.5)
# plt.xlabel("Product Weight (g)")
# plt.ylabel("Freight Cost")
# plt.title("Product Weight vs Freight Cost")
# plt.show()

# Question 10: Does order delivery time affect product ordering?
orders["delivery_time_days"] = (pd.to_datetime(orders["order_delivered_customer_date"]) - pd.to_datetime(orders["order_purchase_timestamp"])).dt.days
sns.histplot(orders["delivery_time_days"], bins=20, kde=True, color='purple')
plt.xlabel("Delivery Time (Days)")
plt.ylabel("Number of Orders")
plt.title("Distribution of Delivery Time for Orders")
plt.show()
# Out:
#                              seller_id  total_revenue
# 857   4869f7a5dfa277a7dca6462dcf3b52b2      229472.63
# 1013  53243585a1d6dc2643021fd1853d8905      222776.05
# 881   4a3ca9315b744ce9f8e9374361493884      200472.92
# 3024  fa1c13f2614d7b5c4749cbc52fecda94      194042.03
# 1535  7c67e1448b00f6e969d365cea6b010ab      187923.89
# 1560  7e93a43ef30c4f03f38b393420bc753a      176431.87
# 2643  da8622b14eb17ae2831f4ac5b9dab84a      160236.57
# 1505  7a67c85e85bb2ce8582c35f2203ad736      141745.53
# 192   1025f0e2d44d7041d6cf58b6550e0bfa      138968.55
# 1824  955fee9216a65b617aa5c0531780ce60      135171.70
#                             customer_id                          order_id  \
# 77630  00012a2ce6f8dcda20d059ce98491703  5f79b5b0931d63f1a42989eb65b9da6e
# 11269  000161a058600d5901f007fab4c27140  a44895d095d7e0702b6a162fa2dbeced
# 74560  0001fd6190edaaf884bcaf3d49edf079  316a104623542e4d75189bb372bc5f8d
# 48874  0002414f95344307404f0ace7a26f1d5  5825ce2e88d5346438686b0bba99e5ee
# 6612   000379cdec625522490c315e70c7a9fb  0ab7fb08086d4af9141453c91878ed7a
# 83373  0004164d20a9e969af783496f3408652  cd3558a10d854487b4f907e9b326a4fc
# 52198  000419c5494106c306a97b5635748086  07f6c3baf9ac86865b60f640c4f923c6
# 67852  00046a560d407e99b969756e0b10f282  8c3d752c5c02227878fae49aeaddbfd7
# 89663  00050bf6e01e69d5c0fd612f1bcfb69c  fa906f338cee30a984d0945b3832e431
# 90907  000598caf2ef4117407665ac33275130  9b961b894e797f63622137ff7eb1c1af
#
#       order_purchase_timestamp  order_value  moving_avg_order_value
# 77630      2017-11-14 16:08:26       114.74                  114.74
# 11269      2017-07-16 09:40:32        67.41                   67.41
# 74560      2017-02-28 11:06:43       195.42                  195.42
# 48874      2017-08-16 13:09:20       179.35                  179.35
# 6612       2018-04-02 13:42:17       107.01                  107.01
# 83373      2017-04-12 08:35:12        71.80                   71.80
# 52198      2018-03-02 17:47:40        49.40                   49.40
# 67852      2017-12-18 11:08:30       166.59                  166.59
# 89663      2017-09-17 16:04:44        85.23                   85.23
# 90907      2018-08-11 12:14:35      1255.71                 1255.71
# Retained Customers (reordered within 6 months): 0
# Total Customers: 99441
# Customer Retention Rate: 0.00%
